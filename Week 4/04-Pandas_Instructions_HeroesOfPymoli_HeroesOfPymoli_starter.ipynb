# %% [markdown]
# ### Heroes Of Pymoli Data Analysis
# * Of the 1163 active players, the vast majority are male (84%). There also exists, a smaller, but notable proportion of female players (14%).
#
# * Our peak age demographic falls between 20-24 (44.8%) with secondary groups falling between 15-19 (18.60%) and 25-29 (13.4%).
# -----

# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd
import numpy as np

# File to Load (Remember to Change These)
file_to_load = "purchase_data.csv"

# Read Purchasing File and store into Pandas data frame
purchase_data = pd.read_csv(file_to_load)

# %%
purchase_data.columns
# Out:
# Index(['Purchase ID', 'SN', 'Age', 'Gender', 'Item ID', 'Item Name', 'Price'], dtype='object')

# %% [markdown]
# ## Player Count

# %% [markdown]
# * Display the total number of players

# %%
total_players = purchase_data['SN'].nunique()
TP = pd.DataFrame({"Total Players": [total_players]})
TP
# Out:
#    Total Players
# 0            576

# %% [markdown]
# ## Purchasing Analysis (Total)

# %% [markdown]
# * Run basic calculations to obtain number of unique items, average price, etc.
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
unique_items = len(purchase_data['Item ID'].value_counts())
avg_purchase_total = purchase_data["Price"].mean()

total_purchases = len(purchase_data["Price"])

total_revenue = purchase_data["Price"].sum()

purchasing_analysis_df = pd.DataFrame({"Number of unique items": unique_items,
                                       "Average price": avg_purchase_total,
                                       "Number of purchases": total_purchases,
                                       "Total revenue": total_revenue}, index = [0])

purchasing_analysis_df["Average price"] = purchasing_analysis_df["Average price"].map("${:.2f}".format)
purchasing_analysis_df["Total revenue"] = purchasing_analysis_df["Total revenue"].map("${:.2f}".format)

purchasing_analysis_df
# Out:
#    Number of unique items Average price  Number of purchases Total revenue
# 0                     183         $3.05                  780      $2379.77

# %% [markdown]
# ## Gender Demographics

# %% [markdown]
# * Percentage and Count of Male Players
#
#
# * Percentage and Count of Female Players
#
#
# * Percentage and Count of Other / Non-Disclosed

# %%
gender_group = purchase_data.groupby('Gender')
unique_members = gender_group['SN'].nunique()

gender_data = pd.DataFrame({'Total Counts': unique_members, 'Percentage of Players': 100*unique_members/total_players})

gender_data["Percentage of Players"] = gender_data["Percentage of Players"].map("{:.2f}".format)
gender_data
# Out:
#                        Total Counts Percentage of Players
# Gender
# Female                           81                 14.06
# Male                            484                 84.03
# Other / Non-Disclosed            11                  1.91

# %% [markdown]
# ## Purchasing Analysis (Gender)

# %% [markdown]
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. by gender
#
#
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
purchase_count = gender_group['Age'].count()
avg_purchase = gender_group["Price"].mean()
total_p_value = gender_group['Price'].sum()
purchasing_analysis_gender = pd.DataFrame({'Purchase count': purchase_count,
                                           'Average purchase price': avg_purchase,
                                           'Total purchase value': total_p_value, 
                                           'Normalized Total': total_p_value/unique_members})
purchasing_analysis_gender["Average purchase price"] = purchasing_analysis_gender["Average purchase price"].map("${:.2f}".format)
purchasing_analysis_gender["Total purchase value"] = purchasing_analysis_gender["Total purchase value"].map("${:.2f}".format)
purchasing_analysis_gender["Normalized Total"] = purchasing_analysis_gender["Normalized Total"].map("${:.2f}".format)

purchasing_analysis_gender
# Out:
#                        Purchase count Average purchase price  \
# Gender
# Female                            113                  $3.20
# Male                              652                  $3.02
# Other / Non-Disclosed              15                  $3.35
#
#                       Total purchase value Normalized Total
# Gender
# Female                             $361.94            $4.47
# Male                              $1967.64            $4.07
# Other / Non-Disclosed               $50.19            $4.56

# %% [markdown]
# ## Age Demographics

# %% [markdown]
# * Establish bins for ages
#
#
# * Categorize the existing players using the age bins. Hint: use pd.cut()
#
#
# * Calculate the numbers and percentages by age group
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: round the percentage column to two decimal points
#
#
# * Display Age Demographics Table

# %%
bins = [0, 9.5, 14.5, 19.5, 24.5, 29.5, 34.5, 39.5, 1000]

bin_labels = ["<10", "10-14", "15-19", "20-24", "25-29", "30-34", "35-39", "40+"]

purchase_data["Age group"] = pd.cut(purchase_data["Age"], bins, labels = bin_labels)

age_group = purchase_data.groupby("Age group")
unique_members = age_group["SN"].nunique()

age_demo = pd.DataFrame({"Total Counts": age_group["SN"].nunique(),
                           "Percentage of Players": 100*unique_members/total_players})

age_demo["Percentage of Players"] = age_demo["Percentage of Players"].map("{:.2f}".format)

age_demo
# Out:
#            Total Counts Percentage of Players
# Age group
# <10                  17                  2.95
# 10-14                22                  3.82
# 15-19               107                 18.58
# 20-24               258                 44.79
# 25-29                77                 13.37
# 30-34                52                  9.03
# 35-39                31                  5.38
# 40+                  12                  2.08

# %% [markdown]
# ## Purchasing Analysis (Age)

# %% [markdown]
# * Bin the purchase_data data frame by age
#
#
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
purchase_count = age_group["Age"].count()
avg_purchase = age_group["Price"].mean()
total_p_value = age_group["Price"].sum()


purchasing_analysis = pd.DataFrame({"Purchase count": purchase_count,
                                       "Average purchase price": avg_purchase,
                                       "Total purchase value": total_p_value,
                                        "Normalized Total": total_p_value/unique_members})
purchasing_analysis
# Out:
#            Purchase count  Average purchase price  Total purchase value  \
# Age group
# <10                    23                3.353478                 77.13
# 10-14                  28                2.956429                 82.78
# 15-19                 136                3.035956                412.89
# 20-24                 365                3.052219               1114.06
# 25-29                 101                2.900990                293.00
# 30-34                  73                2.931507                214.00
# 35-39                  41                3.601707                147.67
# 40+                    13                2.941538                 38.24
#
#            Normalized Total
# Age group
# <10                4.537059
# 10-14              3.762727
# 15-19              3.858785
# 20-24              4.318062
# 25-29              3.805195
# 30-34              4.115385
# 35-39              4.763548
# 40+                3.186667

# %% [markdown]
# ## Top Spenders

# %% [markdown]
# * Run basic calculations to obtain the results in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the total purchase value column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
spending_group = purchase_data.groupby("SN")

purchase_count = spending_group["Age"].count()
avg_purchase = spending_group["Price"].mean()
total_p_value = spending_group["Price"].sum()

top_purchasers = pd.DataFrame({"Purchase count": purchase_count,
                                       "Average purchase price": avg_purchase,
                                       "Total purchase value": total_p_value})


top_purchasers = top_purchasers.sort_values("Total purchase value", ascending = False)


# top 5 rows of the dataframe
top_purchasers.iloc[0:5,:]
# Out:
#                Purchase count  Average purchase price  Total purchase value
# SN
# Lisosia93                   5                3.792000                 18.96
# Idastidru52                 4                3.862500                 15.45
# Chamjask73                  3                4.610000                 13.83
# Iral74                      4                3.405000                 13.62
# Iskadarya95                 3                4.366667                 13.10
# Ilarin91                    3                4.233333                 12.70
# Ialallo29                   3                3.946667                 11.84
# Tyidaim51                   3                3.943333                 11.83
# Lassilsala30                3                3.836667                 11.51
# Chadolyla44                 3                3.820000                 11.46
# Iri67                       3                3.790000                 11.37
# ...

# %% [markdown]
# ## Most Popular Items

# %% [markdown]
# * Retrieve the Item ID, Item Name, and Item Price columns
#
#
# * Group by Item ID and Item Name. Perform calculations to obtain purchase count, item price, and total purchase value
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the purchase count column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
items_group = purchase_data.groupby(["Item ID", "Item Name"])

purchase_count = items_group["Age"].count()
total_p_value = items_group["Price"].sum()
item_price = items_group["Price"].max() 

top_items = pd.DataFrame({"Purchase count": purchase_count,
                                       "Item price": item_price,
                                       "Total purchase value": total_p_value})


top_items = top_items.sort_values("Purchase count", ascending = False)

items_group = purchase_data.groupby(["Item ID", "Item Name"])

purchase_count = items_group["Age"].count()
total_p_value = items_group["Price"].sum()
item_price = items_group["Price"].max() 

top_items= pd.DataFrame({"Purchase count": purchase_count,
                                       "Item price": item_price,
                                       "Total purchase value": total_p_value})


top_items = top_items.sort_values("Purchase count", ascending = False)


#top_items["Total purchase value"] = top_items["Total purchase value"].map("{:.2f}".format)
#top_items["Item price"] = top_items["Item price"].map("{:.2f}".format)


top_items.iloc[0:5,:]
top_items["Total purchase value"] = top_items["Total purchase value"].map("${:.2f}".format)
top_items["Item price"] = top_items["Item price"].map("${:.2f}".format)


top_items.iloc[0:5,:]
# Out:
#                                                       Purchase count  \
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm              12
# 145     Fiery Glass Crusader                                       9
# 108     Extraction, Quickblade Of Trembling Hands                  9
# 82      Nirvana                                                    9
# 19      Pursuit, Cudgel of Necromancy                              8
#
#                                                      Item price  \
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm      $4.23
# 145     Fiery Glass Crusader                              $4.58
# 108     Extraction, Quickblade Of Trembling Hands         $3.53
# 82      Nirvana                                           $4.90
# 19      Pursuit, Cudgel of Necromancy                     $1.02
#
#                                                      Total purchase value
# Item ID Item Name
# ...

# %% [markdown]
# ## Most Profitable Items

# %% [markdown]
# * Sort the above table by total purchase value in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the data frame

# %%
top_items = pd.DataFrame({"Purchase count": purchase_count,
                                       "Item price": item_price,
                                       "Total purchase value": total_p_value})


top_items = top_items.sort_values("Total purchase value", ascending = False)

#top_items["Total purchase value"] = top_items["Total purchase value"].map("${:.2f}".format)
#top_items["Item price"] = top_items["Item price"].map("${:.2f}".format)


top_items.iloc[0:5,:]
# Out:
#                                                       Purchase count  \
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm              12
# 82      Nirvana                                                    9
# 145     Fiery Glass Crusader                                       9
# 92      Final Critic                                               8
# 103     Singed Scalpel                                             8
#
#                                                       Item price  \
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm        4.23
# 82      Nirvana                                             4.90
# 145     Fiery Glass Crusader                                4.58
# 92      Final Critic                                        4.88
# 103     Singed Scalpel                                      4.35
#
#                                                       Total purchase value
# Item ID Item Name
# ...
