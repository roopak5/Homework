# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
output_data_file.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-fe8bc5e25e98> in <module>
# ----> 1 output_data_file.head()
#
# AttributeError: 'str' object has no attribute 'head'

# %%
print(api_key)

# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# %%
# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
     
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# %%
# Print the city count to confirm sufficient count
len(cities)
# Out:
# 601

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
len(url)
# Out:
# 47

# %%
query_url=f"{url}appid={api_key}&q=california"
response = requests.get(query_url).json()
#response

# %%
from time import sleep

# %%
sleep(1)

# %%
# print(f"Beginning Data Retrieval\n-----------------------------")

# city_record = 1
# set_record = 0



# for i in range(len(cities)):
#     if (i) % 50 == 0:
#         city_record = 0
#         set_record += 1
#     print(f"Processing Record {city_record} of Set {set_record} is for | {cities[i]}")
#     city_record += 1
#     #set_record += 1

# print(f"------------------------------\nData Retrieval Complete\n------------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 0 of Set 1 is for | arraial do cabo
# Processing Record 1 of Set 1 is for | dingle
# Processing Record 2 of Set 1 is for | carnarvon
# Processing Record 3 of Set 1 is for | saleaula
# Processing Record 4 of Set 1 is for | hobart
# Processing Record 5 of Set 1 is for | ushuaia
# Processing Record 6 of Set 1 is for | pathein
# Processing Record 7 of Set 1 is for | samusu
# Processing Record 8 of Set 1 is for | saldanha
# Processing Record 9 of Set 1 is for | nelspruit
# Processing Record 10 of Set 1 is for | vaini
# Processing Record 11 of Set 1 is for | dasoguz
# Processing Record 12 of Set 1 is for | bluff
# Processing Record 13 of Set 1 is for | takoradi
# Processing Record 14 of Set 1 is for | barentsburg
# Processing Record 15 of Set 1 is for | lethem
# Processing Record 16 of Set 1 is for | ospitaletto
# Processing Record 17 of Set 1 is for | omboue
# Processing Record 18 of Set 1 is for | gaoual
# Processing Record 19 of Set 1 is for | sosnovo-ozerskoye
# Processing Record 20 of Set 1 is for | heihe
# Processing Record 21 of Set 1 is for | port alfred
# Processing Record 22 of Set 1 is for | rikitea
# Processing Record 23 of Set 1 is for | gurskoye
# Processing Record 24 of Set 1 is for | albany
# Processing Record 25 of Set 1 is for | victoria
# Processing Record 26 of Set 1 is for | belushya guba
# Processing Record 27 of Set 1 is for | boa vista
# Processing Record 28 of Set 1 is for | amberieu-en-bugey
# Processing Record 29 of Set 1 is for | karamea
# Processing Record 30 of Set 1 is for | rafaela
# Processing Record 31 of Set 1 is for | qaanaaq
# Processing Record 32 of Set 1 is for | phan rang
# Processing Record 33 of Set 1 is for | atuona
# Processing Record 34 of Set 1 is for | bilma
# Processing Record 35 of Set 1 is for | lavrentiya
# Processing Record 36 of Set 1 is for | provideniya
# Processing Record 37 of Set 1 is for | butaritari
# Processing Record 38 of Set 1 is for | saskylakh
# Processing Record 39 of Set 1 is for | codrington
# Processing Record 40 of Set 1 is for | taolanaro
# Processing Record 41 of Set 1 is for | lagoa
# Processing Record 42 of Set 1 is for | kruisfontein
# Processing Record 43 of Set 1 is for | kaitangata
# Processing Record 44 of Set 1 is for | belaya gora
# Processing Record 45 of Set 1 is for | mataura
# Processing Record 46 of Set 1 is for | yar-sale
# Processing Record 47 of Set 1 is for | kosamba
# Processing Record 48 of Set 1 is for | bhakkar
# Processing Record 49 of Set 1 is for | jamestown
# Processing Record 0 of Set 2 is for | khalabat
# Processing Record 1 of Set 2 is for | saint george
# Processing Record 2 of Set 2 is for | castro
# Processing Record 3 of Set 2 is for | constitucion
# Processing Record 4 of Set 2 is for | isabela
# Processing Record 5 of Set 2 is for | cherskiy
# Processing Record 6 of Set 2 is for | busselton
# Processing Record 7 of Set 2 is for | luzhou
# Processing Record 8 of Set 2 is for | cabo san lucas
# Processing Record 9 of Set 2 is for | puerto ayora
# Processing Record 10 of Set 2 is for | east london
# Processing Record 11 of Set 2 is for | pevek
# Processing Record 12 of Set 2 is for | vila franca do campo
# Processing Record 13 of Set 2 is for | bargal
# Processing Record 14 of Set 2 is for | kapaa
# Processing Record 15 of Set 2 is for | saint-philippe
# Processing Record 16 of Set 2 is for | tiksi
# Processing Record 17 of Set 2 is for | hithadhoo
# Processing Record 18 of Set 2 is for | tuktoyaktuk
# Processing Record 19 of Set 2 is for | ponta do sol
# Processing Record 20 of Set 2 is for | muriti
# Processing Record 21 of Set 2 is for | beringovskiy
# Processing Record 22 of Set 2 is for | minot
# Processing Record 23 of Set 2 is for | tashtyp
# Processing Record 24 of Set 2 is for | nelson bay
# Processing Record 25 of Set 2 is for | satuk
# Processing Record 26 of Set 2 is for | yellowknife
# Processing Record 27 of Set 2 is for | daokou
# Processing Record 28 of Set 2 is for | mkushi
# Processing Record 29 of Set 2 is for | thompson
# Processing Record 30 of Set 2 is for | severo-kurilsk
# Processing Record 31 of Set 2 is for | avarua
# Processing Record 32 of Set 2 is for | grand gaube
# Processing Record 33 of Set 2 is for | komsomolskiy
# Processing Record 34 of Set 2 is for | burica
# Processing Record 35 of Set 2 is for | bredasdorp
# Processing Record 36 of Set 2 is for | dikson
# Processing Record 37 of Set 2 is for | milove
# Processing Record 38 of Set 2 is for | ormara
# Processing Record 39 of Set 2 is for | tiarei
# Processing Record 40 of Set 2 is for | torbay
# Processing Record 41 of Set 2 is for | bambous virieux
# Processing Record 42 of Set 2 is for | syracuse
# Processing Record 43 of Set 2 is for | pangnirtung
# Processing Record 44 of Set 2 is for | goryachegorsk
# Processing Record 45 of Set 2 is for | alofi
# Processing Record 46 of Set 2 is for | poum
# Processing Record 47 of Set 2 is for | klaksvik
# Processing Record 48 of Set 2 is for | mahebourg
# Processing Record 49 of Set 2 is for | marrakesh
# Processing Record 0 of Set 3 is for | san policarpo
# Processing Record 1 of Set 3 is for | nanortalik
# Processing Record 2 of Set 3 is for | vernon
# Processing Record 3 of Set 3 is for | hilo
# Processing Record 4 of Set 3 is for | fairbanks
# Processing Record 5 of Set 3 is for | black forest
# Processing Record 6 of Set 3 is for | danielskuil
# Processing Record 7 of Set 3 is for | punta arenas
# Processing Record 8 of Set 3 is for | bulungu
# Processing Record 9 of Set 3 is for | imbituba
# Processing Record 10 of Set 3 is for | mucurapo
# Processing Record 11 of Set 3 is for | aklavik
# Processing Record 12 of Set 3 is for | coulihaut
# Processing Record 13 of Set 3 is for | crossville
# Processing Record 14 of Set 3 is for | zelenoborskiy
# Processing Record 15 of Set 3 is for | budapest
# Processing Record 16 of Set 3 is for | ulaangom
# Processing Record 17 of Set 3 is for | urumqi
# Processing Record 18 of Set 3 is for | brae
# Processing Record 19 of Set 3 is for | airai
# Processing Record 20 of Set 3 is for | strai
# Processing Record 21 of Set 3 is for | ruteng
# Processing Record 22 of Set 3 is for | linhares
# Processing Record 23 of Set 3 is for | murray bridge
# Processing Record 24 of Set 3 is for | narsaq
# Processing Record 25 of Set 3 is for | pisco
# Processing Record 26 of Set 3 is for | esperance
# Processing Record 27 of Set 3 is for | madison
# Processing Record 28 of Set 3 is for | staunton
# Processing Record 29 of Set 3 is for | new norfolk
# Processing Record 30 of Set 3 is for | halalo
# Processing Record 31 of Set 3 is for | fort-shevchenko
# Processing Record 32 of Set 3 is for | chinsali
# Processing Record 33 of Set 3 is for | port lincoln
# Processing Record 34 of Set 3 is for | anchorage
# Processing Record 35 of Set 3 is for | tuxpan
# Processing Record 36 of Set 3 is for | katsuura
# Processing Record 37 of Set 3 is for | tondano
# Processing Record 38 of Set 3 is for | ancud
# Processing Record 39 of Set 3 is for | hermanus
# Processing Record 40 of Set 3 is for | chapais
# Processing Record 41 of Set 3 is for | chokurdakh
# Processing Record 42 of Set 3 is for | karaton
# Processing Record 43 of Set 3 is for | namatanai
# Processing Record 44 of Set 3 is for | georgetown
# Processing Record 45 of Set 3 is for | obo
# Processing Record 46 of Set 3 is for | anadyr
# Processing Record 47 of Set 3 is for | ilulissat
# Processing Record 48 of Set 3 is for | clyde river
# Processing Record 49 of Set 3 is for | karratha
# Processing Record 0 of Set 4 is for | masunga
# Processing Record 1 of Set 4 is for | sabang
# Processing Record 2 of Set 4 is for | antofagasta
# Processing Record 3 of Set 4 is for | san cristobal
# Processing Record 4 of Set 4 is for | kodiak
# Processing Record 5 of Set 4 is for | kavieng
# Processing Record 6 of Set 4 is for | los llanos de aridane
# Processing Record 7 of Set 4 is for | kalengwa
# Processing Record 8 of Set 4 is for | jarjis
# Processing Record 9 of Set 4 is for | ucluelet
# Processing Record 10 of Set 4 is for | kampot
# Processing Record 11 of Set 4 is for | vila velha
# Processing Record 12 of Set 4 is for | alice town
# Processing Record 13 of Set 4 is for | olafsvik
# Processing Record 14 of Set 4 is for | panjwin
# Processing Record 15 of Set 4 is for | rzhanitsa
# Processing Record 16 of Set 4 is for | limoges
# Processing Record 17 of Set 4 is for | upernavik
# Processing Record 18 of Set 4 is for | lompoc
# Processing Record 19 of Set 4 is for | bengkulu
# Processing Record 20 of Set 4 is for | shimoda
# Processing Record 21 of Set 4 is for | jundia
# Processing Record 22 of Set 4 is for | salihorsk
# Processing Record 23 of Set 4 is for | san patricio
# Processing Record 24 of Set 4 is for | salalah
# Processing Record 25 of Set 4 is for | barra do corda
# Processing Record 26 of Set 4 is for | oranjemund
# Processing Record 27 of Set 4 is for | slave lake
# Processing Record 28 of Set 4 is for | mouila
# Processing Record 29 of Set 4 is for | illoqqortoormiut
# Processing Record 30 of Set 4 is for | barrow
# Processing Record 31 of Set 4 is for | kununurra
# Processing Record 32 of Set 4 is for | manat
# Processing Record 33 of Set 4 is for | shizunai
# Processing Record 34 of Set 4 is for | masvingo
# Processing Record 35 of Set 4 is for | haines junction
# Processing Record 36 of Set 4 is for | daru
# Processing Record 37 of Set 4 is for | erenhot
# Processing Record 38 of Set 4 is for | barreiras
# Processing Record 39 of Set 4 is for | girvan
# Processing Record 40 of Set 4 is for | tucuman
# Processing Record 41 of Set 4 is for | bilibino
# Processing Record 42 of Set 4 is for | kagadi
# Processing Record 43 of Set 4 is for | puerto del rosario
# Processing Record 44 of Set 4 is for | lubango
# Processing Record 45 of Set 4 is for | fort nelson
# Processing Record 46 of Set 4 is for | voh
# Processing Record 47 of Set 4 is for | casablanca
# Processing Record 48 of Set 4 is for | norman wells
# Processing Record 49 of Set 4 is for | pyay
# Processing Record 0 of Set 5 is for | san quintin
# Processing Record 1 of Set 5 is for | katangli
# Processing Record 2 of Set 5 is for | tuatapere
# Processing Record 3 of Set 5 is for | ribeira grande
# Processing Record 4 of Set 5 is for | carmen
# Processing Record 5 of Set 5 is for | swellendam
# Processing Record 6 of Set 5 is for | mitsamiouli
# Processing Record 7 of Set 5 is for | el bagre
# Processing Record 8 of Set 5 is for | sorong
# Processing Record 9 of Set 5 is for | nikolskoye
# Processing Record 10 of Set 5 is for | cape town
# Processing Record 11 of Set 5 is for | rio gallegos
# Processing Record 12 of Set 5 is for | tall kayf
# Processing Record 13 of Set 5 is for | sambava
# Processing Record 14 of Set 5 is for | ushumun
# Processing Record 15 of Set 5 is for | cidreira
# Processing Record 16 of Set 5 is for | biskamzha
# Processing Record 17 of Set 5 is for | churapcha
# Processing Record 18 of Set 5 is for | wamba
# Processing Record 19 of Set 5 is for | mar del plata
# Processing Record 20 of Set 5 is for | jardim
# Processing Record 21 of Set 5 is for | lebu
# Processing Record 22 of Set 5 is for | attawapiskat
# Processing Record 23 of Set 5 is for | te anau
# Processing Record 24 of Set 5 is for | mackay
# Processing Record 25 of Set 5 is for | salinopolis
# Processing Record 26 of Set 5 is for | tarudant
# Processing Record 27 of Set 5 is for | novokizhinginsk
# Processing Record 28 of Set 5 is for | gravelbourg
# Processing Record 29 of Set 5 is for | ugoofaaru
# Processing Record 30 of Set 5 is for | port antonio
# Processing Record 31 of Set 5 is for | okhotsk
# Processing Record 32 of Set 5 is for | yarmouth
# Processing Record 33 of Set 5 is for | isangel
# Processing Record 34 of Set 5 is for | yendi
# Processing Record 35 of Set 5 is for | kamenka
# Processing Record 36 of Set 5 is for | monrovia
# Processing Record 37 of Set 5 is for | roald
# Processing Record 38 of Set 5 is for | hobyo
# Processing Record 39 of Set 5 is for | togur
# Processing Record 40 of Set 5 is for | mortka
# Processing Record 41 of Set 5 is for | tabiauea
# Processing Record 42 of Set 5 is for | turtkul
# Processing Record 43 of Set 5 is for | nizhneyansk
# Processing Record 44 of Set 5 is for | havre-saint-pierre
# Processing Record 45 of Set 5 is for | thinadhoo
# Processing Record 46 of Set 5 is for | faya
# Processing Record 47 of Set 5 is for | tocopilla
# Processing Record 48 of Set 5 is for | tungkang
# Processing Record 49 of Set 5 is for | george town
# Processing Record 0 of Set 6 is for | beipiao
# Processing Record 1 of Set 6 is for | bermeo
# Processing Record 2 of Set 6 is for | bani walid
# Processing Record 3 of Set 6 is for | longyearbyen
# Processing Record 4 of Set 6 is for | sherlovaya gora
# Processing Record 5 of Set 6 is for | panaba
# Processing Record 6 of Set 6 is for | palabuhanratu
# Processing Record 7 of Set 6 is for | broome
# Processing Record 8 of Set 6 is for | hambantota
# Processing Record 9 of Set 6 is for | macultepec
# Processing Record 10 of Set 6 is for | yulara
# Processing Record 11 of Set 6 is for | dunedin
# Processing Record 12 of Set 6 is for | zaraza
# Processing Record 13 of Set 6 is for | morris
# Processing Record 14 of Set 6 is for | loa janan
# Processing Record 15 of Set 6 is for | port hardy
# Processing Record 16 of Set 6 is for | poli
# Processing Record 17 of Set 6 is for | yerbogachen
# Processing Record 18 of Set 6 is for | kiunga
# Processing Record 19 of Set 6 is for | orlik
# Processing Record 20 of Set 6 is for | berbera
# Processing Record 21 of Set 6 is for | doka
# Processing Record 22 of Set 6 is for | lata
# Processing Record 23 of Set 6 is for | hays
# Processing Record 24 of Set 6 is for | miri
# Processing Record 25 of Set 6 is for | erzin
# Processing Record 26 of Set 6 is for | gumdag
# Processing Record 27 of Set 6 is for | liepaja
# Processing Record 28 of Set 6 is for | batagay-alyta
# Processing Record 29 of Set 6 is for | mariental
# Processing Record 30 of Set 6 is for | chuy
# Processing Record 31 of Set 6 is for | amapa
# Processing Record 32 of Set 6 is for | surt
# Processing Record 33 of Set 6 is for | geraldton
# Processing Record 34 of Set 6 is for | benevides
# Processing Record 35 of Set 6 is for | itarema
# Processing Record 36 of Set 6 is for | zapolyarnyy
# Processing Record 37 of Set 6 is for | coquimbo
# Processing Record 38 of Set 6 is for | kismayo
# Processing Record 39 of Set 6 is for | leh
# Processing Record 40 of Set 6 is for | elliot
# Processing Record 41 of Set 6 is for | sorland
# Processing Record 42 of Set 6 is for | sainte-marie
# Processing Record 43 of Set 6 is for | yanliang
# Processing Record 44 of Set 6 is for | caravelas
# Processing Record 45 of Set 6 is for | ternate
# Processing Record 46 of Set 6 is for | saint-francois
# Processing Record 47 of Set 6 is for | bayburt
# Processing Record 48 of Set 6 is for | praya
# Processing Record 49 of Set 6 is for | wagar
# Processing Record 0 of Set 7 is for | mahadday weyne
# Processing Record 1 of Set 7 is for | szigetvar
# Processing Record 2 of Set 7 is for | rawson
# Processing Record 3 of Set 7 is for | uniontown
# Processing Record 4 of Set 7 is for | santa rosa
# Processing Record 5 of Set 7 is for | khatanga
# Processing Record 6 of Set 7 is for | bull savanna
# Processing Record 7 of Set 7 is for | petersburg
# Processing Record 8 of Set 7 is for | margate
# Processing Record 9 of Set 7 is for | lakes entrance
# Processing Record 10 of Set 7 is for | inhambane
# Processing Record 11 of Set 7 is for | santa cruz cabralia
# Processing Record 12 of Set 7 is for | sarakhs
# Processing Record 13 of Set 7 is for | lokosovo
# Processing Record 14 of Set 7 is for | coihaique
# Processing Record 15 of Set 7 is for | petropavlovsk-kamchatskiy
# Processing Record 16 of Set 7 is for | cayenne
# Processing Record 17 of Set 7 is for | corsicana
# Processing Record 18 of Set 7 is for | muravlenko
# Processing Record 19 of Set 7 is for | thilogne
# Processing Record 20 of Set 7 is for | aksu
# Processing Record 21 of Set 7 is for | terrace
# Processing Record 22 of Set 7 is for | aswan
# Processing Record 23 of Set 7 is for | kargil
# Processing Record 24 of Set 7 is for | iqaluit
# Processing Record 25 of Set 7 is for | mys shmidta
# Processing Record 26 of Set 7 is for | boali
# Processing Record 27 of Set 7 is for | waipawa
# Processing Record 28 of Set 7 is for | tual
# Processing Record 29 of Set 7 is for | satitoa
# Processing Record 30 of Set 7 is for | broken hill
# Processing Record 31 of Set 7 is for | paungde
# Processing Record 32 of Set 7 is for | oriximina
# Processing Record 33 of Set 7 is for | kijang
# Processing Record 34 of Set 7 is for | grand river south east
# Processing Record 35 of Set 7 is for | colombia
# Processing Record 36 of Set 7 is for | bavly
# Processing Record 37 of Set 7 is for | hami
# Processing Record 38 of Set 7 is for | bolu
# Processing Record 39 of Set 7 is for | key biscayne
# Processing Record 40 of Set 7 is for | aksarka
# Processing Record 41 of Set 7 is for | mitu
# Processing Record 42 of Set 7 is for | grindavik
# Processing Record 43 of Set 7 is for | acajutla
# Processing Record 44 of Set 7 is for | marathon
# Processing Record 45 of Set 7 is for | faanui
# Processing Record 46 of Set 7 is for | porto novo
# Processing Record 47 of Set 7 is for | sao filipe
# Processing Record 48 of Set 7 is for | bethel
# Processing Record 49 of Set 7 is for | luganville
# Processing Record 0 of Set 8 is for | ruatoria
# Processing Record 1 of Set 8 is for | ayan
# Processing Record 2 of Set 8 is for | eskasem
# Processing Record 3 of Set 8 is for | san andres
# Processing Record 4 of Set 8 is for | iquique
# Processing Record 5 of Set 8 is for | igarape-acu
# Processing Record 6 of Set 8 is for | sovetskiy
# Processing Record 7 of Set 8 is for | taltal
# Processing Record 8 of Set 8 is for | kavaratti
# Processing Record 9 of Set 8 is for | vostok
# Processing Record 10 of Set 8 is for | igunga
# Processing Record 11 of Set 8 is for | rungata
# Processing Record 12 of Set 8 is for | egvekinot
# Processing Record 13 of Set 8 is for | ampanihy
# Processing Record 14 of Set 8 is for | hashtgerd
# Processing Record 15 of Set 8 is for | bur gabo
# Processing Record 16 of Set 8 is for | mbuji-mayi
# Processing Record 17 of Set 8 is for | manyana
# Processing Record 18 of Set 8 is for | sumbawa
# Processing Record 19 of Set 8 is for | niquero
# Processing Record 20 of Set 8 is for | baijiantan
# Processing Record 21 of Set 8 is for | tasiilaq
# Processing Record 22 of Set 8 is for | lima
# Processing Record 23 of Set 8 is for | kautokeino
# Processing Record 24 of Set 8 is for | oksfjord
# Processing Record 25 of Set 8 is for | kjopsvik
# Processing Record 26 of Set 8 is for | shunyi
# Processing Record 27 of Set 8 is for | sentyabrskiy
# Processing Record 28 of Set 8 is for | camacupa
# Processing Record 29 of Set 8 is for | raudeberg
# Processing Record 30 of Set 8 is for | mount isa
# Processing Record 31 of Set 8 is for | beaumont
# Processing Record 32 of Set 8 is for | naze
# Processing Record 33 of Set 8 is for | saint simons
# Processing Record 34 of Set 8 is for | san luis
# Processing Record 35 of Set 8 is for | bemidji
# Processing Record 36 of Set 8 is for | kahului
# Processing Record 37 of Set 8 is for | chicama
# Processing Record 38 of Set 8 is for | fomboni
# Processing Record 39 of Set 8 is for | luanda
# Processing Record 40 of Set 8 is for | matadi
# Processing Record 41 of Set 8 is for | sheltozero
# Processing Record 42 of Set 8 is for | buala
# Processing Record 43 of Set 8 is for | rabaul
# Processing Record 44 of Set 8 is for | vestbygda
# Processing Record 45 of Set 8 is for | krasnovishersk
# Processing Record 46 of Set 8 is for | ojinaga
# Processing Record 47 of Set 8 is for | viljoenskroon
# Processing Record 48 of Set 8 is for | orocue
# Processing Record 49 of Set 8 is for | japura
# Processing Record 0 of Set 9 is for | bathsheba
# Processing Record 1 of Set 9 is for | marcona
# Processing Record 2 of Set 9 is for | mabaruma
# Processing Record 3 of Set 9 is for | cheyenne
# Processing Record 4 of Set 9 is for | nyurba
# Processing Record 5 of Set 9 is for | boundiali
# Processing Record 6 of Set 9 is for | simbahan
# Processing Record 7 of Set 9 is for | goderich
# Processing Record 8 of Set 9 is for | namibe
# Processing Record 9 of Set 9 is for | lasa
# Processing Record 10 of Set 9 is for | touros
# Processing Record 11 of Set 9 is for | palmer
# Processing Record 12 of Set 9 is for | atambua
# Processing Record 13 of Set 9 is for | batagay
# Processing Record 14 of Set 9 is for | porto calvo
# Processing Record 15 of Set 9 is for | acapulco
# Processing Record 16 of Set 9 is for | vestmannaeyjar
# Processing Record 17 of Set 9 is for | morehead
# Processing Record 18 of Set 9 is for | lugoba
# Processing Record 19 of Set 9 is for | vaitupu
# Processing Record 20 of Set 9 is for | uige
# Processing Record 21 of Set 9 is for | perth
# Processing Record 22 of Set 9 is for | talnakh
# Processing Record 23 of Set 9 is for | cascais
# Processing Record 24 of Set 9 is for | den helder
# Processing Record 25 of Set 9 is for | bafra
# Processing Record 26 of Set 9 is for | kon tum
# Processing Record 27 of Set 9 is for | pontes e lacerda
# Processing Record 28 of Set 9 is for | flinders
# Processing Record 29 of Set 9 is for | puri
# Processing Record 30 of Set 9 is for | umm lajj
# Processing Record 31 of Set 9 is for | seminole
# Processing Record 32 of Set 9 is for | keti bandar
# Processing Record 33 of Set 9 is for | minas
# Processing Record 34 of Set 9 is for | verkhoyansk
# Processing Record 35 of Set 9 is for | alyangula
# Processing Record 36 of Set 9 is for | sistranda
# Processing Record 37 of Set 9 is for | sioux lookout
# Processing Record 38 of Set 9 is for | tura
# Processing Record 39 of Set 9 is for | winslow
# Processing Record 40 of Set 9 is for | cradock
# Processing Record 41 of Set 9 is for | kolaras
# Processing Record 42 of Set 9 is for | susangerd
# Processing Record 43 of Set 9 is for | djibo
# Processing Record 44 of Set 9 is for | amderma
# Processing Record 45 of Set 9 is for | vaovai
# Processing Record 46 of Set 9 is for | kamenskoye
# Processing Record 47 of Set 9 is for | mount gambier
# Processing Record 48 of Set 9 is for | codajas
# Processing Record 49 of Set 9 is for | darjiling
# Processing Record 0 of Set 10 is for | barueri
# Processing Record 1 of Set 10 is for | chernyakhiv
# Processing Record 2 of Set 10 is for | vestmanna
# Processing Record 3 of Set 10 is for | umba
# Processing Record 4 of Set 10 is for | road town
# Processing Record 5 of Set 10 is for | panzhihua
# Processing Record 6 of Set 10 is for | yen bai
# Processing Record 7 of Set 10 is for | narasannapeta
# Processing Record 8 of Set 10 is for | tezu
# Processing Record 9 of Set 10 is for | itaituba
# Processing Record 10 of Set 10 is for | sao miguel do araguaia
# Processing Record 11 of Set 10 is for | garowe
# Processing Record 12 of Set 10 is for | mayo
# Processing Record 13 of Set 10 is for | noyabrsk
# Processing Record 14 of Set 10 is for | vao
# Processing Record 15 of Set 10 is for | uvat
# Processing Record 16 of Set 10 is for | souillac
# Processing Record 17 of Set 10 is for | jacareacanga
# Processing Record 18 of Set 10 is for | saint-pierre
# Processing Record 19 of Set 10 is for | meulaboh
# Processing Record 20 of Set 10 is for | maturin
# Processing Record 21 of Set 10 is for | apalit
# Processing Record 22 of Set 10 is for | merauke
# Processing Record 23 of Set 10 is for | huilong
# Processing Record 24 of Set 10 is for | laguna
# Processing Record 25 of Set 10 is for | ocos
# Processing Record 26 of Set 10 is for | hai phong
# Processing Record 27 of Set 10 is for | acarau
# Processing Record 28 of Set 10 is for | oromocto
# Processing Record 29 of Set 10 is for | chumikan
# Processing Record 30 of Set 10 is for | kalabo
# Processing Record 31 of Set 10 is for | daman
# Processing Record 32 of Set 10 is for | kurilsk
# Processing Record 33 of Set 10 is for | thaba-tseka
# Processing Record 34 of Set 10 is for | manokwari
# Processing Record 35 of Set 10 is for | bukachacha
# Processing Record 36 of Set 10 is for | saint anthony
# Processing Record 37 of Set 10 is for | pochutla
# Processing Record 38 of Set 10 is for | boende
# Processing Record 39 of Set 10 is for | tumannyy
# Processing Record 40 of Set 10 is for | feijo
# Processing Record 41 of Set 10 is for | san joaquin
# Processing Record 42 of Set 10 is for | gorontalo
# Processing Record 43 of Set 10 is for | haibowan
# Processing Record 44 of Set 10 is for | yauya
# Processing Record 45 of Set 10 is for | hamilton
# Processing Record 46 of Set 10 is for | panguna
# Processing Record 47 of Set 10 is for | beaufort
# Processing Record 48 of Set 10 is for | gucheng
# Processing Record 49 of Set 10 is for | businga
# Processing Record 0 of Set 11 is for | chagda
# Processing Record 1 of Set 11 is for | tahoua
# Processing Record 2 of Set 11 is for | tanshui
# Processing Record 3 of Set 11 is for | soubre
# Processing Record 4 of Set 11 is for | hasaki
# Processing Record 5 of Set 11 is for | villanueva
# Processing Record 6 of Set 11 is for | wahran
# Processing Record 7 of Set 11 is for | carutapera
# Processing Record 8 of Set 11 is for | guerrero negro
# Processing Record 9 of Set 11 is for | nantucket
# Processing Record 10 of Set 11 is for | mirabad
# Processing Record 11 of Set 11 is for | challapata
# Processing Record 12 of Set 11 is for | matara
# Processing Record 13 of Set 11 is for | vardo
# Processing Record 14 of Set 11 is for | banda aceh
# Processing Record 15 of Set 11 is for | port elizabeth
# Processing Record 16 of Set 11 is for | menongue
# Processing Record 17 of Set 11 is for | magaria
# Processing Record 18 of Set 11 is for | jaicos
# Processing Record 19 of Set 11 is for | kabare
# Processing Record 20 of Set 11 is for | lorengau
# Processing Record 21 of Set 11 is for | portland
# Processing Record 22 of Set 11 is for | khandyga
# Processing Record 23 of Set 11 is for | georgiyevskoye
# Processing Record 24 of Set 11 is for | awjilah
# Processing Record 25 of Set 11 is for | talara
# Processing Record 26 of Set 11 is for | port hawkesbury
# Processing Record 27 of Set 11 is for | tsihombe
# Processing Record 28 of Set 11 is for | boone
# Processing Record 29 of Set 11 is for | avera
# Processing Record 30 of Set 11 is for | nkhata bay
# Processing Record 31 of Set 11 is for | verkhnyaya inta
# Processing Record 32 of Set 11 is for | davidson
# Processing Record 33 of Set 11 is for | melilla
# Processing Record 34 of Set 11 is for | maple creek
# Processing Record 35 of Set 11 is for | deputatskiy
# Processing Record 36 of Set 11 is for | ganzhou
# Processing Record 37 of Set 11 is for | omsukchan
# Processing Record 38 of Set 11 is for | chihuahua
# Processing Record 39 of Set 11 is for | opochka
# Processing Record 40 of Set 11 is for | tukrah
# Processing Record 41 of Set 11 is for | luderitz
# Processing Record 42 of Set 11 is for | kizlyar
# Processing Record 43 of Set 11 is for | richards bay
# Processing Record 44 of Set 11 is for | leningradskiy
# Processing Record 45 of Set 11 is for | sataua
# Processing Record 46 of Set 11 is for | bereda
# Processing Record 47 of Set 11 is for | alenquer
# Processing Record 48 of Set 11 is for | kawana waters
# Processing Record 49 of Set 11 is for | nishihara
# Processing Record 0 of Set 12 is for | barawe
# Processing Record 1 of Set 12 is for | ossora
# Processing Record 2 of Set 12 is for | bo phloi
# Processing Record 3 of Set 12 is for | dezhou
# Processing Record 4 of Set 12 is for | virginia beach
# Processing Record 5 of Set 12 is for | gat
# Processing Record 6 of Set 12 is for | nyuksenitsa
# Processing Record 7 of Set 12 is for | sabha
# Processing Record 8 of Set 12 is for | ostrovnoy
# Processing Record 9 of Set 12 is for | padang
# Processing Record 10 of Set 12 is for | ekhabi
# Processing Record 11 of Set 12 is for | davila
# Processing Record 12 of Set 12 is for | bondoukou
# Processing Record 13 of Set 12 is for | roma
# Processing Record 14 of Set 12 is for | teguldet
# Processing Record 15 of Set 12 is for | westerland
# Processing Record 16 of Set 12 is for | ippy
# Processing Record 17 of Set 12 is for | baykit
# Processing Record 18 of Set 12 is for | berlevag
# Processing Record 19 of Set 12 is for | dauphin
# Processing Record 20 of Set 12 is for | khanpur
# Processing Record 21 of Set 12 is for | ihosy
# Processing Record 22 of Set 12 is for | shrigonda
# Processing Record 23 of Set 12 is for | alcala
# Processing Record 24 of Set 12 is for | port blair
# Processing Record 25 of Set 12 is for | alta floresta
# Processing Record 26 of Set 12 is for | pointe-noire
# Processing Record 27 of Set 12 is for | kieta
# Processing Record 28 of Set 12 is for | gemena
# Processing Record 29 of Set 12 is for | port arthur
# Processing Record 30 of Set 12 is for | montepuez
# Processing Record 31 of Set 12 is for | college
# Processing Record 32 of Set 12 is for | pervomayskiy
# Processing Record 33 of Set 12 is for | lebowakgomo
# Processing Record 34 of Set 12 is for | sao joao da barra
# Processing Record 35 of Set 12 is for | novyy urgal
# Processing Record 36 of Set 12 is for | san lorenzo
# Processing Record 37 of Set 12 is for | normandin
# Processing Record 38 of Set 12 is for | kawalu
# Processing Record 39 of Set 12 is for | atar
# Processing Record 40 of Set 12 is for | gamba
# Processing Record 41 of Set 12 is for | sept-iles
# Processing Record 42 of Set 12 is for | antalaha
# Processing Record 43 of Set 12 is for | tarauaca
# Processing Record 44 of Set 12 is for | maningrida
# Processing Record 45 of Set 12 is for | kizukuri
# Processing Record 46 of Set 12 is for | kyle of lochalsh
# Processing Record 47 of Set 12 is for | bokovskaya
# Processing Record 48 of Set 12 is for | nichinan
# Processing Record 49 of Set 12 is for | seguin
# Processing Record 0 of Set 13 is for | laiagam
# ------------------------------
# Data Retrieval Complete
# ------------------------------

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
print(f"Beginning Data Retrieval\n-----------------------------")

city_record = 1
set_record = 0

for i in range(len(cities)):
    if (i) % 50 == 0:
        city_record = 0
        set_record += 1
    print(f"Processing Record {city_record} of Set {set_record} is for | {cities[i]}")
    city_record += 1
    #set_record += 1
try:
        cities_df = (requests.get(url + '&q=' + cities)).json()
        City.append(cities_df['name'])
        Lat.append(cities_df['coord']['lat'])
        Lng.append(cities_df['coord']['lon'])
        Max_Temp.append(cities_df['main']['temp'])
        Humidity.append(cities_df['main']['humidity'])
        Cloudiness.append(cities_df['clouds']['all'])
        Wind_Speed.append(cities_df['wind']['speed'])
        print(f"Processing Record {city_record} of Set {set_record} is for | {cities[i]}")
        city_record += 1
        set_record += 1

except KeyError:
       print(f'City not found. Skipping...{city_record} of {len(cities)}. | Skipping {cities[i]}')
        
print(f"------------------------------\nData Retrieval Complete\n------------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 0 of Set 1 is for | arraial do cabo
# Processing Record 1 of Set 1 is for | dingle
# Processing Record 2 of Set 1 is for | carnarvon
# Processing Record 3 of Set 1 is for | saleaula
# Processing Record 4 of Set 1 is for | hobart
# Processing Record 5 of Set 1 is for | ushuaia
# Processing Record 6 of Set 1 is for | pathein
# Processing Record 7 of Set 1 is for | samusu
# Processing Record 8 of Set 1 is for | saldanha
# Processing Record 9 of Set 1 is for | nelspruit
# Processing Record 10 of Set 1 is for | vaini
# Processing Record 11 of Set 1 is for | dasoguz
# Processing Record 12 of Set 1 is for | bluff
# Processing Record 13 of Set 1 is for | takoradi
# Processing Record 14 of Set 1 is for | barentsburg
# Processing Record 15 of Set 1 is for | lethem
# Processing Record 16 of Set 1 is for | ospitaletto
# Processing Record 17 of Set 1 is for | omboue
# Processing Record 18 of Set 1 is for | gaoual
# Processing Record 19 of Set 1 is for | sosnovo-ozerskoye
# Processing Record 20 of Set 1 is for | heihe
# Processing Record 21 of Set 1 is for | port alfred
# Processing Record 22 of Set 1 is for | rikitea
# Processing Record 23 of Set 1 is for | gurskoye
# Processing Record 24 of Set 1 is for | albany
# Processing Record 25 of Set 1 is for | victoria
# Processing Record 26 of Set 1 is for | belushya guba
# Processing Record 27 of Set 1 is for | boa vista
# Processing Record 28 of Set 1 is for | amberieu-en-bugey
# Processing Record 29 of Set 1 is for | karamea
# Processing Record 30 of Set 1 is for | rafaela
# Processing Record 31 of Set 1 is for | qaanaaq
# Processing Record 32 of Set 1 is for | phan rang
# Processing Record 33 of Set 1 is for | atuona
# Processing Record 34 of Set 1 is for | bilma
# Processing Record 35 of Set 1 is for | lavrentiya
# Processing Record 36 of Set 1 is for | provideniya
# Processing Record 37 of Set 1 is for | butaritari
# Processing Record 38 of Set 1 is for | saskylakh
# Processing Record 39 of Set 1 is for | codrington
# Processing Record 40 of Set 1 is for | taolanaro
# Processing Record 41 of Set 1 is for | lagoa
# Processing Record 42 of Set 1 is for | kruisfontein
# Processing Record 43 of Set 1 is for | kaitangata
# Processing Record 44 of Set 1 is for | belaya gora
# Processing Record 45 of Set 1 is for | mataura
# Processing Record 46 of Set 1 is for | yar-sale
# Processing Record 47 of Set 1 is for | kosamba
# Processing Record 48 of Set 1 is for | bhakkar
# Processing Record 49 of Set 1 is for | jamestown
# Processing Record 0 of Set 2 is for | khalabat
# Processing Record 1 of Set 2 is for | saint george
# Processing Record 2 of Set 2 is for | castro
# Processing Record 3 of Set 2 is for | constitucion
# Processing Record 4 of Set 2 is for | isabela
# Processing Record 5 of Set 2 is for | cherskiy
# Processing Record 6 of Set 2 is for | busselton
# Processing Record 7 of Set 2 is for | luzhou
# Processing Record 8 of Set 2 is for | cabo san lucas
# Processing Record 9 of Set 2 is for | puerto ayora
# Processing Record 10 of Set 2 is for | east london
# Processing Record 11 of Set 2 is for | pevek
# Processing Record 12 of Set 2 is for | vila franca do campo
# Processing Record 13 of Set 2 is for | bargal
# Processing Record 14 of Set 2 is for | kapaa
# Processing Record 15 of Set 2 is for | saint-philippe
# Processing Record 16 of Set 2 is for | tiksi
# Processing Record 17 of Set 2 is for | hithadhoo
# Processing Record 18 of Set 2 is for | tuktoyaktuk
# Processing Record 19 of Set 2 is for | ponta do sol
# Processing Record 20 of Set 2 is for | muriti
# Processing Record 21 of Set 2 is for | beringovskiy
# Processing Record 22 of Set 2 is for | minot
# Processing Record 23 of Set 2 is for | tashtyp
# Processing Record 24 of Set 2 is for | nelson bay
# Processing Record 25 of Set 2 is for | satuk
# Processing Record 26 of Set 2 is for | yellowknife
# Processing Record 27 of Set 2 is for | daokou
# Processing Record 28 of Set 2 is for | mkushi
# Processing Record 29 of Set 2 is for | thompson
# Processing Record 30 of Set 2 is for | severo-kurilsk
# Processing Record 31 of Set 2 is for | avarua
# Processing Record 32 of Set 2 is for | grand gaube
# Processing Record 33 of Set 2 is for | komsomolskiy
# Processing Record 34 of Set 2 is for | burica
# Processing Record 35 of Set 2 is for | bredasdorp
# Processing Record 36 of Set 2 is for | dikson
# Processing Record 37 of Set 2 is for | milove
# Processing Record 38 of Set 2 is for | ormara
# Processing Record 39 of Set 2 is for | tiarei
# Processing Record 40 of Set 2 is for | torbay
# Processing Record 41 of Set 2 is for | bambous virieux
# Processing Record 42 of Set 2 is for | syracuse
# Processing Record 43 of Set 2 is for | pangnirtung
# Processing Record 44 of Set 2 is for | goryachegorsk
# Processing Record 45 of Set 2 is for | alofi
# Processing Record 46 of Set 2 is for | poum
# Processing Record 47 of Set 2 is for | klaksvik
# Processing Record 48 of Set 2 is for | mahebourg
# Processing Record 49 of Set 2 is for | marrakesh
# Processing Record 0 of Set 3 is for | san policarpo
# Processing Record 1 of Set 3 is for | nanortalik
# Processing Record 2 of Set 3 is for | vernon
# Processing Record 3 of Set 3 is for | hilo
# Processing Record 4 of Set 3 is for | fairbanks
# Processing Record 5 of Set 3 is for | black forest
# Processing Record 6 of Set 3 is for | danielskuil
# Processing Record 7 of Set 3 is for | punta arenas
# Processing Record 8 of Set 3 is for | bulungu
# Processing Record 9 of Set 3 is for | imbituba
# Processing Record 10 of Set 3 is for | mucurapo
# Processing Record 11 of Set 3 is for | aklavik
# Processing Record 12 of Set 3 is for | coulihaut
# Processing Record 13 of Set 3 is for | crossville
# Processing Record 14 of Set 3 is for | zelenoborskiy
# Processing Record 15 of Set 3 is for | budapest
# Processing Record 16 of Set 3 is for | ulaangom
# Processing Record 17 of Set 3 is for | urumqi
# Processing Record 18 of Set 3 is for | brae
# Processing Record 19 of Set 3 is for | airai
# Processing Record 20 of Set 3 is for | strai
# Processing Record 21 of Set 3 is for | ruteng
# Processing Record 22 of Set 3 is for | linhares
# Processing Record 23 of Set 3 is for | murray bridge
# Processing Record 24 of Set 3 is for | narsaq
# Processing Record 25 of Set 3 is for | pisco
# Processing Record 26 of Set 3 is for | esperance
# Processing Record 27 of Set 3 is for | madison
# Processing Record 28 of Set 3 is for | staunton
# Processing Record 29 of Set 3 is for | new norfolk
# Processing Record 30 of Set 3 is for | halalo
# Processing Record 31 of Set 3 is for | fort-shevchenko
# Processing Record 32 of Set 3 is for | chinsali
# Processing Record 33 of Set 3 is for | port lincoln
# Processing Record 34 of Set 3 is for | anchorage
# Processing Record 35 of Set 3 is for | tuxpan
# Processing Record 36 of Set 3 is for | katsuura
# Processing Record 37 of Set 3 is for | tondano
# Processing Record 38 of Set 3 is for | ancud
# Processing Record 39 of Set 3 is for | hermanus
# Processing Record 40 of Set 3 is for | chapais
# Processing Record 41 of Set 3 is for | chokurdakh
# Processing Record 42 of Set 3 is for | karaton
# Processing Record 43 of Set 3 is for | namatanai
# Processing Record 44 of Set 3 is for | georgetown
# Processing Record 45 of Set 3 is for | obo
# Processing Record 46 of Set 3 is for | anadyr
# Processing Record 47 of Set 3 is for | ilulissat
# Processing Record 48 of Set 3 is for | clyde river
# Processing Record 49 of Set 3 is for | karratha
# Processing Record 0 of Set 4 is for | masunga
# Processing Record 1 of Set 4 is for | sabang
# Processing Record 2 of Set 4 is for | antofagasta
# Processing Record 3 of Set 4 is for | san cristobal
# Processing Record 4 of Set 4 is for | kodiak
# Processing Record 5 of Set 4 is for | kavieng
# Processing Record 6 of Set 4 is for | los llanos de aridane
# Processing Record 7 of Set 4 is for | kalengwa
# Processing Record 8 of Set 4 is for | jarjis
# Processing Record 9 of Set 4 is for | ucluelet
# Processing Record 10 of Set 4 is for | kampot
# Processing Record 11 of Set 4 is for | vila velha
# Processing Record 12 of Set 4 is for | alice town
# Processing Record 13 of Set 4 is for | olafsvik
# Processing Record 14 of Set 4 is for | panjwin
# Processing Record 15 of Set 4 is for | rzhanitsa
# Processing Record 16 of Set 4 is for | limoges
# Processing Record 17 of Set 4 is for | upernavik
# Processing Record 18 of Set 4 is for | lompoc
# Processing Record 19 of Set 4 is for | bengkulu
# Processing Record 20 of Set 4 is for | shimoda
# Processing Record 21 of Set 4 is for | jundia
# Processing Record 22 of Set 4 is for | salihorsk
# Processing Record 23 of Set 4 is for | san patricio
# Processing Record 24 of Set 4 is for | salalah
# Processing Record 25 of Set 4 is for | barra do corda
# Processing Record 26 of Set 4 is for | oranjemund
# Processing Record 27 of Set 4 is for | slave lake
# Processing Record 28 of Set 4 is for | mouila
# Processing Record 29 of Set 4 is for | illoqqortoormiut
# Processing Record 30 of Set 4 is for | barrow
# Processing Record 31 of Set 4 is for | kununurra
# Processing Record 32 of Set 4 is for | manat
# Processing Record 33 of Set 4 is for | shizunai
# Processing Record 34 of Set 4 is for | masvingo
# Processing Record 35 of Set 4 is for | haines junction
# Processing Record 36 of Set 4 is for | daru
# Processing Record 37 of Set 4 is for | erenhot
# Processing Record 38 of Set 4 is for | barreiras
# Processing Record 39 of Set 4 is for | girvan
# Processing Record 40 of Set 4 is for | tucuman
# Processing Record 41 of Set 4 is for | bilibino
# Processing Record 42 of Set 4 is for | kagadi
# Processing Record 43 of Set 4 is for | puerto del rosario
# Processing Record 44 of Set 4 is for | lubango
# Processing Record 45 of Set 4 is for | fort nelson
# Processing Record 46 of Set 4 is for | voh
# Processing Record 47 of Set 4 is for | casablanca
# Processing Record 48 of Set 4 is for | norman wells
# Processing Record 49 of Set 4 is for | pyay
# Processing Record 0 of Set 5 is for | san quintin
# Processing Record 1 of Set 5 is for | katangli
# Processing Record 2 of Set 5 is for | tuatapere
# Processing Record 3 of Set 5 is for | ribeira grande
# Processing Record 4 of Set 5 is for | carmen
# Processing Record 5 of Set 5 is for | swellendam
# Processing Record 6 of Set 5 is for | mitsamiouli
# Processing Record 7 of Set 5 is for | el bagre
# Processing Record 8 of Set 5 is for | sorong
# Processing Record 9 of Set 5 is for | nikolskoye
# Processing Record 10 of Set 5 is for | cape town
# Processing Record 11 of Set 5 is for | rio gallegos
# Processing Record 12 of Set 5 is for | tall kayf
# Processing Record 13 of Set 5 is for | sambava
# Processing Record 14 of Set 5 is for | ushumun
# Processing Record 15 of Set 5 is for | cidreira
# Processing Record 16 of Set 5 is for | biskamzha
# Processing Record 17 of Set 5 is for | churapcha
# Processing Record 18 of Set 5 is for | wamba
# Processing Record 19 of Set 5 is for | mar del plata
# Processing Record 20 of Set 5 is for | jardim
# Processing Record 21 of Set 5 is for | lebu
# Processing Record 22 of Set 5 is for | attawapiskat
# Processing Record 23 of Set 5 is for | te anau
# Processing Record 24 of Set 5 is for | mackay
# Processing Record 25 of Set 5 is for | salinopolis
# Processing Record 26 of Set 5 is for | tarudant
# Processing Record 27 of Set 5 is for | novokizhinginsk
# Processing Record 28 of Set 5 is for | gravelbourg
# Processing Record 29 of Set 5 is for | ugoofaaru
# Processing Record 30 of Set 5 is for | port antonio
# Processing Record 31 of Set 5 is for | okhotsk
# Processing Record 32 of Set 5 is for | yarmouth
# Processing Record 33 of Set 5 is for | isangel
# Processing Record 34 of Set 5 is for | yendi
# Processing Record 35 of Set 5 is for | kamenka
# Processing Record 36 of Set 5 is for | monrovia
# Processing Record 37 of Set 5 is for | roald
# Processing Record 38 of Set 5 is for | hobyo
# Processing Record 39 of Set 5 is for | togur
# Processing Record 40 of Set 5 is for | mortka
# Processing Record 41 of Set 5 is for | tabiauea
# Processing Record 42 of Set 5 is for | turtkul
# Processing Record 43 of Set 5 is for | nizhneyansk
# Processing Record 44 of Set 5 is for | havre-saint-pierre
# Processing Record 45 of Set 5 is for | thinadhoo
# Processing Record 46 of Set 5 is for | faya
# Processing Record 47 of Set 5 is for | tocopilla
# Processing Record 48 of Set 5 is for | tungkang
# Processing Record 49 of Set 5 is for | george town
# Processing Record 0 of Set 6 is for | beipiao
# Processing Record 1 of Set 6 is for | bermeo
# Processing Record 2 of Set 6 is for | bani walid
# Processing Record 3 of Set 6 is for | longyearbyen
# Processing Record 4 of Set 6 is for | sherlovaya gora
# Processing Record 5 of Set 6 is for | panaba
# Processing Record 6 of Set 6 is for | palabuhanratu
# Processing Record 7 of Set 6 is for | broome
# Processing Record 8 of Set 6 is for | hambantota
# Processing Record 9 of Set 6 is for | macultepec
# Processing Record 10 of Set 6 is for | yulara
# Processing Record 11 of Set 6 is for | dunedin
# Processing Record 12 of Set 6 is for | zaraza
# Processing Record 13 of Set 6 is for | morris
# Processing Record 14 of Set 6 is for | loa janan
# Processing Record 15 of Set 6 is for | port hardy
# Processing Record 16 of Set 6 is for | poli
# Processing Record 17 of Set 6 is for | yerbogachen
# Processing Record 18 of Set 6 is for | kiunga
# Processing Record 19 of Set 6 is for | orlik
# Processing Record 20 of Set 6 is for | berbera
# Processing Record 21 of Set 6 is for | doka
# Processing Record 22 of Set 6 is for | lata
# Processing Record 23 of Set 6 is for | hays
# Processing Record 24 of Set 6 is for | miri
# Processing Record 25 of Set 6 is for | erzin
# Processing Record 26 of Set 6 is for | gumdag
# Processing Record 27 of Set 6 is for | liepaja
# Processing Record 28 of Set 6 is for | batagay-alyta
# Processing Record 29 of Set 6 is for | mariental
# Processing Record 30 of Set 6 is for | chuy
# Processing Record 31 of Set 6 is for | amapa
# Processing Record 32 of Set 6 is for | surt
# Processing Record 33 of Set 6 is for | geraldton
# Processing Record 34 of Set 6 is for | benevides
# Processing Record 35 of Set 6 is for | itarema
# Processing Record 36 of Set 6 is for | zapolyarnyy
# Processing Record 37 of Set 6 is for | coquimbo
# Processing Record 38 of Set 6 is for | kismayo
# Processing Record 39 of Set 6 is for | leh
# Processing Record 40 of Set 6 is for | elliot
# Processing Record 41 of Set 6 is for | sorland
# Processing Record 42 of Set 6 is for | sainte-marie
# Processing Record 43 of Set 6 is for | yanliang
# Processing Record 44 of Set 6 is for | caravelas
# Processing Record 45 of Set 6 is for | ternate
# Processing Record 46 of Set 6 is for | saint-francois
# Processing Record 47 of Set 6 is for | bayburt
# Processing Record 48 of Set 6 is for | praya
# Processing Record 49 of Set 6 is for | wagar
# Processing Record 0 of Set 7 is for | mahadday weyne
# Processing Record 1 of Set 7 is for | szigetvar
# Processing Record 2 of Set 7 is for | rawson
# Processing Record 3 of Set 7 is for | uniontown
# Processing Record 4 of Set 7 is for | santa rosa
# Processing Record 5 of Set 7 is for | khatanga
# Processing Record 6 of Set 7 is for | bull savanna
# Processing Record 7 of Set 7 is for | petersburg
# Processing Record 8 of Set 7 is for | margate
# Processing Record 9 of Set 7 is for | lakes entrance
# Processing Record 10 of Set 7 is for | inhambane
# Processing Record 11 of Set 7 is for | santa cruz cabralia
# Processing Record 12 of Set 7 is for | sarakhs
# Processing Record 13 of Set 7 is for | lokosovo
# Processing Record 14 of Set 7 is for | coihaique
# Processing Record 15 of Set 7 is for | petropavlovsk-kamchatskiy
# Processing Record 16 of Set 7 is for | cayenne
# Processing Record 17 of Set 7 is for | corsicana
# Processing Record 18 of Set 7 is for | muravlenko
# Processing Record 19 of Set 7 is for | thilogne
# Processing Record 20 of Set 7 is for | aksu
# Processing Record 21 of Set 7 is for | terrace
# Processing Record 22 of Set 7 is for | aswan
# Processing Record 23 of Set 7 is for | kargil
# Processing Record 24 of Set 7 is for | iqaluit
# Processing Record 25 of Set 7 is for | mys shmidta
# Processing Record 26 of Set 7 is for | boali
# Processing Record 27 of Set 7 is for | waipawa
# Processing Record 28 of Set 7 is for | tual
# Processing Record 29 of Set 7 is for | satitoa
# Processing Record 30 of Set 7 is for | broken hill
# Processing Record 31 of Set 7 is for | paungde
# Processing Record 32 of Set 7 is for | oriximina
# Processing Record 33 of Set 7 is for | kijang
# Processing Record 34 of Set 7 is for | grand river south east
# Processing Record 35 of Set 7 is for | colombia
# Processing Record 36 of Set 7 is for | bavly
# Processing Record 37 of Set 7 is for | hami
# Processing Record 38 of Set 7 is for | bolu
# Processing Record 39 of Set 7 is for | key biscayne
# Processing Record 40 of Set 7 is for | aksarka
# Processing Record 41 of Set 7 is for | mitu
# Processing Record 42 of Set 7 is for | grindavik
# Processing Record 43 of Set 7 is for | acajutla
# Processing Record 44 of Set 7 is for | marathon
# Processing Record 45 of Set 7 is for | faanui
# Processing Record 46 of Set 7 is for | porto novo
# Processing Record 47 of Set 7 is for | sao filipe
# Processing Record 48 of Set 7 is for | bethel
# Processing Record 49 of Set 7 is for | luganville
# Processing Record 0 of Set 8 is for | ruatoria
# Processing Record 1 of Set 8 is for | ayan
# Processing Record 2 of Set 8 is for | eskasem
# Processing Record 3 of Set 8 is for | san andres
# Processing Record 4 of Set 8 is for | iquique
# Processing Record 5 of Set 8 is for | igarape-acu
# Processing Record 6 of Set 8 is for | sovetskiy
# Processing Record 7 of Set 8 is for | taltal
# Processing Record 8 of Set 8 is for | kavaratti
# Processing Record 9 of Set 8 is for | vostok
# Processing Record 10 of Set 8 is for | igunga
# Processing Record 11 of Set 8 is for | rungata
# Processing Record 12 of Set 8 is for | egvekinot
# Processing Record 13 of Set 8 is for | ampanihy
# Processing Record 14 of Set 8 is for | hashtgerd
# Processing Record 15 of Set 8 is for | bur gabo
# Processing Record 16 of Set 8 is for | mbuji-mayi
# Processing Record 17 of Set 8 is for | manyana
# Processing Record 18 of Set 8 is for | sumbawa
# Processing Record 19 of Set 8 is for | niquero
# Processing Record 20 of Set 8 is for | baijiantan
# Processing Record 21 of Set 8 is for | tasiilaq
# Processing Record 22 of Set 8 is for | lima
# Processing Record 23 of Set 8 is for | kautokeino
# Processing Record 24 of Set 8 is for | oksfjord
# Processing Record 25 of Set 8 is for | kjopsvik
# Processing Record 26 of Set 8 is for | shunyi
# Processing Record 27 of Set 8 is for | sentyabrskiy
# Processing Record 28 of Set 8 is for | camacupa
# Processing Record 29 of Set 8 is for | raudeberg
# Processing Record 30 of Set 8 is for | mount isa
# Processing Record 31 of Set 8 is for | beaumont
# Processing Record 32 of Set 8 is for | naze
# Processing Record 33 of Set 8 is for | saint simons
# Processing Record 34 of Set 8 is for | san luis
# Processing Record 35 of Set 8 is for | bemidji
# Processing Record 36 of Set 8 is for | kahului
# Processing Record 37 of Set 8 is for | chicama
# Processing Record 38 of Set 8 is for | fomboni
# Processing Record 39 of Set 8 is for | luanda
# Processing Record 40 of Set 8 is for | matadi
# Processing Record 41 of Set 8 is for | sheltozero
# Processing Record 42 of Set 8 is for | buala
# Processing Record 43 of Set 8 is for | rabaul
# Processing Record 44 of Set 8 is for | vestbygda
# Processing Record 45 of Set 8 is for | krasnovishersk
# Processing Record 46 of Set 8 is for | ojinaga
# Processing Record 47 of Set 8 is for | viljoenskroon
# Processing Record 48 of Set 8 is for | orocue
# Processing Record 49 of Set 8 is for | japura
# Processing Record 0 of Set 9 is for | bathsheba
# Processing Record 1 of Set 9 is for | marcona
# Processing Record 2 of Set 9 is for | mabaruma
# Processing Record 3 of Set 9 is for | cheyenne
# Processing Record 4 of Set 9 is for | nyurba
# Processing Record 5 of Set 9 is for | boundiali
# Processing Record 6 of Set 9 is for | simbahan
# Processing Record 7 of Set 9 is for | goderich
# Processing Record 8 of Set 9 is for | namibe
# Processing Record 9 of Set 9 is for | lasa
# Processing Record 10 of Set 9 is for | touros
# Processing Record 11 of Set 9 is for | palmer
# Processing Record 12 of Set 9 is for | atambua
# Processing Record 13 of Set 9 is for | batagay
# Processing Record 14 of Set 9 is for | porto calvo
# Processing Record 15 of Set 9 is for | acapulco
# Processing Record 16 of Set 9 is for | vestmannaeyjar
# Processing Record 17 of Set 9 is for | morehead
# Processing Record 18 of Set 9 is for | lugoba
# Processing Record 19 of Set 9 is for | vaitupu
# Processing Record 20 of Set 9 is for | uige
# Processing Record 21 of Set 9 is for | perth
# Processing Record 22 of Set 9 is for | talnakh
# Processing Record 23 of Set 9 is for | cascais
# Processing Record 24 of Set 9 is for | den helder
# Processing Record 25 of Set 9 is for | bafra
# Processing Record 26 of Set 9 is for | kon tum
# Processing Record 27 of Set 9 is for | pontes e lacerda
# Processing Record 28 of Set 9 is for | flinders
# Processing Record 29 of Set 9 is for | puri
# Processing Record 30 of Set 9 is for | umm lajj
# Processing Record 31 of Set 9 is for | seminole
# Processing Record 32 of Set 9 is for | keti bandar
# Processing Record 33 of Set 9 is for | minas
# Processing Record 34 of Set 9 is for | verkhoyansk
# Processing Record 35 of Set 9 is for | alyangula
# Processing Record 36 of Set 9 is for | sistranda
# Processing Record 37 of Set 9 is for | sioux lookout
# Processing Record 38 of Set 9 is for | tura
# Processing Record 39 of Set 9 is for | winslow
# Processing Record 40 of Set 9 is for | cradock
# Processing Record 41 of Set 9 is for | kolaras
# Processing Record 42 of Set 9 is for | susangerd
# Processing Record 43 of Set 9 is for | djibo
# Processing Record 44 of Set 9 is for | amderma
# Processing Record 45 of Set 9 is for | vaovai
# Processing Record 46 of Set 9 is for | kamenskoye
# Processing Record 47 of Set 9 is for | mount gambier
# Processing Record 48 of Set 9 is for | codajas
# Processing Record 49 of Set 9 is for | darjiling
# Processing Record 0 of Set 10 is for | barueri
# Processing Record 1 of Set 10 is for | chernyakhiv
# Processing Record 2 of Set 10 is for | vestmanna
# Processing Record 3 of Set 10 is for | umba
# Processing Record 4 of Set 10 is for | road town
# Processing Record 5 of Set 10 is for | panzhihua
# Processing Record 6 of Set 10 is for | yen bai
# Processing Record 7 of Set 10 is for | narasannapeta
# Processing Record 8 of Set 10 is for | tezu
# Processing Record 9 of Set 10 is for | itaituba
# Processing Record 10 of Set 10 is for | sao miguel do araguaia
# Processing Record 11 of Set 10 is for | garowe
# Processing Record 12 of Set 10 is for | mayo
# Processing Record 13 of Set 10 is for | noyabrsk
# Processing Record 14 of Set 10 is for | vao
# Processing Record 15 of Set 10 is for | uvat
# Processing Record 16 of Set 10 is for | souillac
# Processing Record 17 of Set 10 is for | jacareacanga
# Processing Record 18 of Set 10 is for | saint-pierre
# Processing Record 19 of Set 10 is for | meulaboh
# Processing Record 20 of Set 10 is for | maturin
# Processing Record 21 of Set 10 is for | apalit
# Processing Record 22 of Set 10 is for | merauke
# Processing Record 23 of Set 10 is for | huilong
# Processing Record 24 of Set 10 is for | laguna
# Processing Record 25 of Set 10 is for | ocos
# Processing Record 26 of Set 10 is for | hai phong
# Processing Record 27 of Set 10 is for | acarau
# Processing Record 28 of Set 10 is for | oromocto
# Processing Record 29 of Set 10 is for | chumikan
# Processing Record 30 of Set 10 is for | kalabo
# Processing Record 31 of Set 10 is for | daman
# Processing Record 32 of Set 10 is for | kurilsk
# Processing Record 33 of Set 10 is for | thaba-tseka
# Processing Record 34 of Set 10 is for | manokwari
# Processing Record 35 of Set 10 is for | bukachacha
# Processing Record 36 of Set 10 is for | saint anthony
# Processing Record 37 of Set 10 is for | pochutla
# Processing Record 38 of Set 10 is for | boende
# Processing Record 39 of Set 10 is for | tumannyy
# Processing Record 40 of Set 10 is for | feijo
# Processing Record 41 of Set 10 is for | san joaquin
# Processing Record 42 of Set 10 is for | gorontalo
# Processing Record 43 of Set 10 is for | haibowan
# Processing Record 44 of Set 10 is for | yauya
# Processing Record 45 of Set 10 is for | hamilton
# Processing Record 46 of Set 10 is for | panguna
# Processing Record 47 of Set 10 is for | beaufort
# Processing Record 48 of Set 10 is for | gucheng
# Processing Record 49 of Set 10 is for | businga
# Processing Record 0 of Set 11 is for | chagda
# Processing Record 1 of Set 11 is for | tahoua
# Processing Record 2 of Set 11 is for | tanshui
# Processing Record 3 of Set 11 is for | soubre
# Processing Record 4 of Set 11 is for | hasaki
# Processing Record 5 of Set 11 is for | villanueva
# Processing Record 6 of Set 11 is for | wahran
# Processing Record 7 of Set 11 is for | carutapera
# Processing Record 8 of Set 11 is for | guerrero negro
# Processing Record 9 of Set 11 is for | nantucket
# Processing Record 10 of Set 11 is for | mirabad
# Processing Record 11 of Set 11 is for | challapata
# Processing Record 12 of Set 11 is for | matara
# Processing Record 13 of Set 11 is for | vardo
# Processing Record 14 of Set 11 is for | banda aceh
# Processing Record 15 of Set 11 is for | port elizabeth
# Processing Record 16 of Set 11 is for | menongue
# Processing Record 17 of Set 11 is for | magaria
# Processing Record 18 of Set 11 is for | jaicos
# Processing Record 19 of Set 11 is for | kabare
# Processing Record 20 of Set 11 is for | lorengau
# Processing Record 21 of Set 11 is for | portland
# Processing Record 22 of Set 11 is for | khandyga
# Processing Record 23 of Set 11 is for | georgiyevskoye
# Processing Record 24 of Set 11 is for | awjilah
# Processing Record 25 of Set 11 is for | talara
# Processing Record 26 of Set 11 is for | port hawkesbury
# Processing Record 27 of Set 11 is for | tsihombe
# Processing Record 28 of Set 11 is for | boone
# Processing Record 29 of Set 11 is for | avera
# Processing Record 30 of Set 11 is for | nkhata bay
# Processing Record 31 of Set 11 is for | verkhnyaya inta
# Processing Record 32 of Set 11 is for | davidson
# Processing Record 33 of Set 11 is for | melilla
# Processing Record 34 of Set 11 is for | maple creek
# Processing Record 35 of Set 11 is for | deputatskiy
# Processing Record 36 of Set 11 is for | ganzhou
# Processing Record 37 of Set 11 is for | omsukchan
# Processing Record 38 of Set 11 is for | chihuahua
# Processing Record 39 of Set 11 is for | opochka
# Processing Record 40 of Set 11 is for | tukrah
# Processing Record 41 of Set 11 is for | luderitz
# Processing Record 42 of Set 11 is for | kizlyar
# Processing Record 43 of Set 11 is for | richards bay
# Processing Record 44 of Set 11 is for | leningradskiy
# Processing Record 45 of Set 11 is for | sataua
# Processing Record 46 of Set 11 is for | bereda
# Processing Record 47 of Set 11 is for | alenquer
# Processing Record 48 of Set 11 is for | kawana waters
# Processing Record 49 of Set 11 is for | nishihara
# Processing Record 0 of Set 12 is for | barawe
# Processing Record 1 of Set 12 is for | ossora
# Processing Record 2 of Set 12 is for | bo phloi
# Processing Record 3 of Set 12 is for | dezhou
# Processing Record 4 of Set 12 is for | virginia beach
# Processing Record 5 of Set 12 is for | gat
# Processing Record 6 of Set 12 is for | nyuksenitsa
# Processing Record 7 of Set 12 is for | sabha
# Processing Record 8 of Set 12 is for | ostrovnoy
# Processing Record 9 of Set 12 is for | padang
# Processing Record 10 of Set 12 is for | ekhabi
# Processing Record 11 of Set 12 is for | davila
# Processing Record 12 of Set 12 is for | bondoukou
# Processing Record 13 of Set 12 is for | roma
# Processing Record 14 of Set 12 is for | teguldet
# Processing Record 15 of Set 12 is for | westerland
# Processing Record 16 of Set 12 is for | ippy
# Processing Record 17 of Set 12 is for | baykit
# Processing Record 18 of Set 12 is for | berlevag
# Processing Record 19 of Set 12 is for | dauphin
# Processing Record 20 of Set 12 is for | khanpur
# Processing Record 21 of Set 12 is for | ihosy
# Processing Record 22 of Set 12 is for | shrigonda
# Processing Record 23 of Set 12 is for | alcala
# Processing Record 24 of Set 12 is for | port blair
# Processing Record 25 of Set 12 is for | alta floresta
# Processing Record 26 of Set 12 is for | pointe-noire
# Processing Record 27 of Set 12 is for | kieta
# Processing Record 28 of Set 12 is for | gemena
# Processing Record 29 of Set 12 is for | port arthur
# Processing Record 30 of Set 12 is for | montepuez
# Processing Record 31 of Set 12 is for | college
# Processing Record 32 of Set 12 is for | pervomayskiy
# Processing Record 33 of Set 12 is for | lebowakgomo
# Processing Record 34 of Set 12 is for | sao joao da barra
# Processing Record 35 of Set 12 is for | novyy urgal
# Processing Record 36 of Set 12 is for | san lorenzo
# Processing Record 37 of Set 12 is for | normandin
# Processing Record 38 of Set 12 is for | kawalu
# Processing Record 39 of Set 12 is for | atar
# Processing Record 40 of Set 12 is for | gamba
# Processing Record 41 of Set 12 is for | sept-iles
# Processing Record 42 of Set 12 is for | antalaha
# Processing Record 43 of Set 12 is for | tarauaca
# Processing Record 44 of Set 12 is for | maningrida
# Processing Record 45 of Set 12 is for | kizukuri
# Processing Record 46 of Set 12 is for | kyle of lochalsh
# Processing Record 47 of Set 12 is for | bokovskaya
# Processing Record 48 of Set 12 is for | nichinan
# Processing Record 49 of Set 12 is for | seguin
# Processing Record 0 of Set 13 is for | laiagam
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-d438ce14e97f> in <module>
#      12     #set_record += 1
#      13 try:
# ---> 14         cities_df = (requests.get(url + '&q=' + cities)).json()
#      15         City.append(cities_df['name'])
#      16         Lat.append(cities_df['coord']['lat'])
#
# TypeError: can only concatenate str (not "list") to str

# %% [markdown]
# Lists

# %%
City = []
Cloudiness = []
Country = []
Date = []
Humidity = []
Lat = []
Lng = []
Max_Temp = []
Wind_Speed = []

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
cities_df  = pd.DataFrame({
    "City": City,                                   #append cities
    "Cloudiness": Cloudiness,
    "Country": Country,
    "Date": Date,
    "Humidity": Humidity,
    "Lat": Lat,
    "Lng": Lng,
    "Max_Temp": Max_Temp,
    "Wind_Speed": Wind_Speed
})

#pd.DataFrame.to_csv('output_data_file')
cities_df.count()
# Out:
# City          0
# Cloudiness    0
# Country       0
# Date          0
# Humidity      0
# Lat           0
# Lng           0
# Max_Temp      0
# Wind_Speed    0
# dtype: int64

# %%
pd.DataFrame.to_csv(cities_df, 'cities_df.csv')
cities_df.head()
# Out:
# Empty DataFrame
# Columns: [City, Cloudiness, Country, Date, Humidity, Lat, Lng, Max_Temp, Wind_Speed]
# Index: []

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# plt.scatter(city_data_df['Latitude'], city_data_df['Temperature'])
# plt.title(f'City Latitude vs. Temperature {date.today()}')
# plt.xlabel('Latitude')
# plt.ylabel('Temperature (F)')
# plt.grid(True)
# plt.savefig('lat_temp.png', bbox_inches='tight')

plt.scatter(cities_df['Lat'], cities_df['Max_Temp'])
plt.title(f'City Latitude vs. Max Temperature(08/22/18)')
plt.xlabel('Latitude')
plt.ylabel('Max_Temperature(F)')
plt.grid(True)          
plt
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\karaj\\Anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(cities_df['Lat'], cities_df['Humidity'])
plt.title(f'City Latitude vs. Humidity')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid(True)
plt
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\karaj\\Anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(cities_df['Lat'], cities_df['Cloudiness'])
plt.title(f'City Latitude vs. Cloudiness')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid(True)
#plt.savefig('lat_cloud.png', bbox_inches='tight')

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(cities_df['Lat'], cities_df['Wind_Speed'])
plt.title(f'City Latitude vs. Wind Speed')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.grid(True)
#plt.savefig('lat_wind.png', bbox_inches='tight')
